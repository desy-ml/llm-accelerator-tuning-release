# %%
import sys

sys.path.append("../")

# %%
from gym.wrappers import TimeLimit

from src.environments import bc, dl, ea, sh
from src.wrappers import PlotEpisode

# %%
env = ea.TransverseTuning(
    backend="cheetah",
    backend_args={"generate_screen_images": True},
    final_combiner_weights=[0.1, 0.1, 1],
)
env = TimeLimit(env, max_episode_steps=10)
env = PlotEpisode(env, save_dir="../plots")

observation, info = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
# Out:
# Overwriting existing episode plots at /Users/jankaiser/Documents/DESY/ares-transverse-tuning/plots folder. Specify a different `save_dir` for the `RecordEpisode` wrapper if this is not desired.

# %%
env = dl.TransverseTuning(
    backend="cheetah",
    backend_args={"generate_screen_images": True},
    final_combiner_weights=[0.1, 0.1, 1],
)
env = TimeLimit(env, max_episode_steps=10)
env = PlotEpisode(env, save_dir="../plots")

observation, info = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
# Out:
# Overwriting existing episode plots at /Users/jankaiser/Documents/DESY/ares-transverse-tuning/plots folder. Specify a different `save_dir` for the `RecordEpisode` wrapper if this is not desired.

# %%
env = sh.TransverseTuning(
    backend="cheetah",
    backend_args={"generate_screen_images": True},
    final_combiner_weights=[0.1, 0.1, 1],
)
env = TimeLimit(env, max_episode_steps=10)
env = PlotEpisode(env, save_dir="../plots")

observation, info = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
# Out:
# Overwriting existing episode plots at /Users/jankaiser/Documents/DESY/ares-transverse-tuning/plots folder. Specify a different `save_dir` for the `RecordEpisode` wrapper if this is not desired.

# %%
env = bc.TransverseTuning(
    backend="cheetah",
    backend_args={"generate_screen_images": True},
    final_combiner_weights=[0.1, 0.1, 1],
)
env = TimeLimit(env, max_episode_steps=10)
env = PlotEpisode(env, save_dir="../plots")

observation, info = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
# Out:
# Overwriting existing episode plots at /Users/jankaiser/Documents/DESY/ares-transverse-tuning/plots folder. Specify a different `save_dir` for the `RecordEpisode` wrapper if this is not desired.
